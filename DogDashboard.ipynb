# %% [markdown]
# # Welcome to the Dog Dashboard

# %%
from DogGenerator import generate_dog
from IPython.display import Image
# Out:
# This dog's picture was generated on September 13, 2017 at 18:25 PM (UTC)
# This dog's picture was generated on September 13, 2017 at 18:25 PM (UTC)

# %%
img, time = generate_dog()

# %%
time
# Out:
# "This dog's picture was generated on September 13, 2017 at 18:25 PM (UTC)"

# %%
Image(img)
