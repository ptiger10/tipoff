# %% [markdown]
# # Welcome to the Dog Dashboard

# %%
from DogGenerator import generate_dog
from IPython.display import Image

# %%
img, time = generate_dog()

# %%
time
# Out:
# 'This dog was generated on September 13, 2017 at 8:01 AM (UTC)'

# %%
Image(img)
