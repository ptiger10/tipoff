# %%
import WeatherComputron

# %% [markdown]
# ### This dashboard computes and displays the most historically unusual weather in California every day
# This dashboard updates every morning.
# In order to maximize data coverage, calculations are based on the date 30 days prior to today.

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on August 18, 2017 was Camp Pendleton Mcas Station.
#         The average temperature that day was 59.5°F, colder than usual.
#         The temperature was 3x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at Camp Pendleton Mcas Station: 71.56°F
#         Standard deviation: 3.84°F
