# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on September 5, 2017 was:
#         Bodega 6 Wsw Station.
#         The average temperature that day was 69.0°F, hotter than usual.
#         The temperature was 4x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at Bodega 6 Wsw Station: 57.39°F
#         Standard deviation: 3.10°F
