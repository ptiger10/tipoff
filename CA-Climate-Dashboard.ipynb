# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on March 29, 2018 was:
#         Imperial Beach Ream Field Nas Station.
#         The average temperature that day was 1.5°F, colder than usual.
#         The temperature was 17x more unusual than the past 51 years of historical precedent.
#
#         Historical average temperature on this day at Imperial Beach Ream Field Nas Station: 58.04°F
#         Standard deviation: 3.31°F
