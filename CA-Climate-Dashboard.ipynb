# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on November 24, 2017 was:
#         Gibraltar Dam Number 2 Station.
#         The average temperature that day was 70.5°F, hotter than usual.
#         The temperature was 20x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at Gibraltar Dam Number 2 Station: 56.50°F
#         Standard deviation: 0.71°F
