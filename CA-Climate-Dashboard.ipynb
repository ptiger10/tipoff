# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on January 30, 2018 was:
#         Rancho Bernardo Station.
#         The average temperature that day was 70.0°F, hotter than usual.
#         The temperature was 5x more unusual than the past 51 years of historical precedent.
#
#         Historical average temperature on this day at Rancho Bernardo Station: 57.29°F
#         Standard deviation: 2.64°F
