# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on October 11, 2017 was:
#         State Line Station.
#         The average temperature that day was 33.5°F, colder than usual.
#         The temperature was 6x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at State Line Station: 51.00°F
#         Standard deviation: 3.04°F
