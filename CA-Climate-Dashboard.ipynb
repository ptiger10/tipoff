# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on September 17, 2017 was:
#         Mount Laguna California Station.
#         The average temperature that day was 54.5°F, colder than usual.
#         The temperature was 2x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at Mount Laguna California Station: 62.55°F
#         Standard deviation: 4.03°F
