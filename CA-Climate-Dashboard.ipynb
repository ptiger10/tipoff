# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on October 10, 2017 was:
#         Aspendell Station.
#         The average temperature that day was 36.0°F, colder than usual.
#         The temperature was 3x more unusual than the past 50 years of historical precedent.
#
#         Historical average temperature on this day at Aspendell Station: 49.00°F
#         Standard deviation: 4.33°F
