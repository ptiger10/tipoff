# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on November 21, 2018 was:
#         Montague Siskiyou Airport Station.
#         The average temperature that day was 53.0°F, hotter than usual.
#         The temperature was 2x more unusual than the past 51 years of historical precedent.
#
#         Historical average temperature on this day at Montague Siskiyou Airport Station: 39.69°F
#         Standard deviation: 5.43°F
