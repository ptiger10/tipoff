# %% [markdown]
# ## This dashboard identifies and profiles highly unusual weather activity
# Updates every day (but runs its analysis on a 30-day lag to allow for optimal data coverage)
#
# Currently focused on California

# %%
import WeatherComputron

# %%
WeatherComputron.visualize_result(start_year='1967', locationid='FIPS:06')
# Out:
#         The CA location with the most unusual weather on January 4, 2018 was:
#         Big Bar California Station.
#         The average temperature that day was 55.0°F, hotter than usual.
#         The temperature was 4x more unusual than the past 51 years of historical precedent.
#
#         Historical average temperature on this day at Big Bar California Station: 41.02°F
#         Standard deviation: 3.93°F
